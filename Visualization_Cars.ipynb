# %% [markdown]
# Get some insights of the test dataset

# %%
import pandas as pd
import numpy as np


PATH_TO_DATA = "/home/said/PycharmProjects/WILL_SCRAPER/CAR_CSVs/Willhaben_CARS_05_04_2023_17_57_04.csv"

# %%
# The example dataset consists of around 300 cars, let's have a look at it
cars_df = pd.read_csv(PATH_TO_DATA)
cars_df.head(10)
# Out:
#                                                Title       Price  \
# 0  (reserviert) Audi 80 Quattro COMPETITION Limou...  Reserviert
# 1  Audi Q3 2,0TDI qu. S-tronic Leder+Navi SUV / G...    € 19.800
# 2          Audi Q8 50 TDI quattro SUV / Geländewagen    € 84.730
# 3         Audi A4 Limousine 35 TFSI S line Limousine    € 37.990
# 4         Audi Q2 30 TFSI intense SUV / Geländewagen    € 30.760
# 5          Audi A4 Audi A4 quadro Kombi / Family Van       € 400
# 6            Audi A4 Avant 35 TDI Kombi / Family Van    € 51.790
# 7        Audi A1 Sportback 25 TFSI intense Limousine    € 26.810
# 8        Audi A3 Sportback 30 TFSI intense Limousine    € 33.990
# 9         Audi A3 Sportback 30 TDI intense Limousine    € 33.910
#
#                                             Location Erstzulassung  \
# 0  4863 Seewalchen am Attersee Vöcklabruck, Oberö...       05/1994
# 1          3500 Krems an der Donau Niederösterreich        04/2013
# ...

# %%
# TODO: Get rid of NaN rows or instead skip Vorbesitzer and Verbrauch column?
